# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Downloads/student_ml_dataset.csv")

# %%
data.head()
# Out:
#                 Name  Age  Gender  Hours_Studied   IQ  Physics_Marks  \
# 0        Derek Smith   26  Female       6.596347   98             68
# 1  Christopher Boyle   37    Male       5.672202  133             44
# 2      Bradley Jones   19    Male       6.282581   89             90
# 3      Eric Martinez   21    Male       8.004422  106             81
# 4   Jennifer Ferrell   29  Female       4.322501   88             41
# 5        Ryan Rangel   40    Male       1.854121  119             58
#
#    Math_Marks  Chemistry_Marks  Has_Part_Time_Job
# 0         100               43               True
# 1          53               92               True
# 2          48               57               True
# 3          88               41              False
# 4          83               85               True
# 5         100               69               True

# %%
data.tail()
# Out:
#                   Name  Age  Gender  Hours_Studied   IQ  Physics_Marks  \
# 995      Jonathan Long   29  Female       4.525427  100             64
# 996     Michael Morgan   34  Female       9.049785  129             70
# 997   Jacob Cunningham   29    Male       5.942553  108             68
# 998  Brittany Matthews   39  Female       5.268965  120             73
# 999      Daniel Kramer   28  Female       9.840650  106             74
#
#      Math_Marks  Chemistry_Marks  Has_Part_Time_Job
# 995          72               63              False
# 996          91               40              False
# 997         100               98               True
# 998          52               87              False
# 999          82               55               True

# %%
data.nunique()
# Out:
# Name                  987
# Age                    28
# Gender                  2
# Hours_Studied        1000
# IQ                     71
# Physics_Marks          61
# Math_Marks             61
# Chemistry_Marks        61
# Has_Part_Time_Job       2
# dtype: int64

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data['Age'].unique()
# Out:
# array([26, 37, 19, 21, 29, 40, 31, 30, 25, 27, 28, 43, 39, 24, 36, 32, 41,
#        34, 45, 42, 20, 35, 44, 18, 33, 22, 38, 23], dtype=int64)

# %%
data.isnull().sum()
# Out:
# Name                 0
# Age                  0
# Gender               0
# Hours_Studied        0
# IQ                   0
# Physics_Marks        0
# Math_Marks           0
# Chemistry_Marks      0
# Has_Part_Time_Job    0
# dtype: int64

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Hours_Studied'}>],
#        [<Axes: title={'center': 'IQ'}>,
#         <Axes: title={'center': 'Physics_Marks'}>],
#        [<Axes: title={'center': 'Math_Marks'}>,
#         <Axes: title={'center': 'Chemistry_Marks'}>]], dtype=object)

# %%
data.iloc[:,0:4].hist(bins=20)
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Hours_Studied'}>]], dtype=object)

# %%
data.iloc[:,0:6].hist(bins="rice")
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Hours_Studied'}>],
#        [<Axes: title={'center': 'IQ'}>,
#         <Axes: title={'center': 'Physics_Marks'}>]], dtype=object)

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Hours_Studied', 'IQ', 'Physics_Marks',
#        'Math_Marks', 'Chemistry_Marks', 'Has_Part_Time_Job'],
#       dtype='object')

# %%
data.iloc[:,0:8].boxplot()
# Out:
# <Axes: >

# %%
data[['IQ','Physics_Marks']].boxplot()
# Out:
# <Axes: >

# %%
 data = pd.read_csv("Downloads/student_ml_dataset.csv")

# %%
sns.pairplot(data.iloc[:,0:5])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
 data = pd.read_csv("Downloads/student_ml_dataset.csv")

# %%
data.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15432\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                         Age  Hours_Studied        IQ  Physics_Marks  \
# Age                1.000000       0.022652  0.011575      -0.038093
# Hours_Studied      0.022652       1.000000  0.004555       0.009470
# IQ                 0.011575       0.004555  1.000000      -0.052473
# Physics_Marks     -0.038093       0.009470 -0.052473       1.000000
# Math_Marks        -0.022445      -0.029683  0.031086      -0.018277
# Chemistry_Marks    0.038762       0.001121  0.002967       0.006725
# Has_Part_Time_Job -0.058760      -0.015860  0.031566       0.009703
#
#                    Math_Marks  Chemistry_Marks  Has_Part_Time_Job
# Age                 -0.022445         0.038762          -0.058760
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr())

plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15432\1706068083.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
